# %%
from catboost import CatBoostRegressor
import streamlit as st
import pandas as pd

model=CatBoostRegressor
model.load_model("model.cbm")

def predict_price(cbm,df):
    pred=model.predict(df)
    return round(pred[0],2)

st.title("mazda fiyat tahminleyicisi")
model_dict={'1996 Mazda MX-5 Miata M Edition': 0,
  '1997 Mazda MX-5 Miata': 1,
  '2002 Mazda 626 LX': 2,
  '2004 Mazda Mazda6 s': 3,
  '2004 Mazda RX-8 Sport Automatic': 4,
  '2006 Mazda MX-5 Miata Touring': 5,
  '2006 Mazda RX-8 6 Speed Manual (M6)': 6,
  '2007 Mazda CX-7 Sport': 7,
  '2007 Mazda CX-7 Touring': 8,
  '2007 Mazda MX-5 Miata Sport': 9,
  '2008 Mazda Mazda3 s Grand Touring': 10,
  '2008 Mazda MazdaSpeed3 Grand Touring': 11,
  '2008 Mazda RX-8 Sport': 12,
  '2009 Mazda Mazda3 i Sport': 13,
  '2009 Mazda MazdaSpeed3 Grand Touring': 14,
  '2010 Mazda CX-9 Grand Touring': 15,
  '2010 Mazda MX-5 Miata Grand Touring': 16,
  '2010 Mazda MX-5 Miata Sport': 17,
  '2010 Mazda Mazda3 i Sport': 18,
  '2010 Mazda Mazda6 i Grand Touring': 19,
  '2010 Mazda Mazda6 i Touring Plus': 20,
  '2011 Mazda CX-7 i SV': 21,
  '2012 Mazda Mazda6 i Touring': 22,
  '2012 Mazda MazdaSpeed3 Touring': 23,
  '2013 Mazda CX-5 Sport': 24,
  '2013 Mazda CX-5 Touring': 25,
  '2013 Mazda CX-9 Grand Touring': 26,
  '2013 Mazda CX-9 Touring': 27,
  '2013 Mazda MX-5 Miata Club': 28,
  '2013 Mazda MX-5 Miata Grand Touring': 29,
  '2013 Mazda Mazda3 i Touring': 30,
  '2013 Mazda Mazda6 i Sport': 31,
  '2013 Mazda Mazda6 i Touring': 32,
  '2014 Mazda CX-5 Grand Touring': 33,
  '2014 Mazda CX-5 Touring': 34,
  '2014 Mazda MX-5 Miata Club': 35,
  '2014 Mazda Mazda2 Sport': 36,
  '2014 Mazda Mazda3 i Sport': 37,
  '2014 Mazda Mazda3 i Touring': 38,
  '2014 Mazda Mazda6 i Grand Touring': 39,
  '2014 Mazda Mazda6 i Touring': 40,
  '2015 Mazda CX-5 Sport': 41,
  '2015 Mazda CX-5 Touring': 42,
  '2015 Mazda CX-9 Grand Touring': 43,
  '2015 Mazda CX-9 Touring': 44,
  '2015 Mazda MX-5 Miata Grand Touring': 45,
  '2015 Mazda MX-5 Miata Sport': 46,
  '2015 Mazda Mazda3 i Grand Touring': 47,
  '2015 Mazda Mazda3 i Sport': 48,
  '2015 Mazda Mazda3 i Touring': 49,
  '2015 Mazda Mazda3 s Touring': 50,
  '2015 Mazda Mazda6 i Touring': 51,
  '2016 Mazda CX-3 Grand Touring': 52,
  '2016 Mazda CX-3 Touring': 53,
  '2016 Mazda CX-5 Grand Touring': 54,
  '2016 Mazda CX-5 Sport': 55,
  '2016 Mazda CX-5 Touring': 56,
  '2016 Mazda CX-9 Touring': 57,
  '2016 Mazda MX-5 Miata Club': 58,
  '2016 Mazda Mazda3 i Sport': 59,
  '2016 Mazda Mazda3 i Touring': 60,
  '2016 Mazda Mazda6 i Grand Touring': 61,
  '2016 Mazda Mazda6 i Sport': 62,
  '2016 Mazda Mazda6 i Touring': 63,
  '2017 Mazda CX-3 Grand Touring': 64,
  '2017 Mazda CX-3 Touring': 65,
  '2017 Mazda CX-5 Sport': 66,
  '2017 Mazda CX-5 Touring': 67,
  '2017 Mazda CX-9 Grand Touring': 68,
  '2017 Mazda CX-9 Sport': 69,
  '2017 Mazda CX-9 Touring': 70,
  '2017 Mazda MX-5 Miata RF Club': 71,
  '2017 Mazda Mazda3 Touring': 72,
  '2017 Mazda Mazda6 Grand Touring': 73,
  '2017 Mazda Mazda6 Sport': 74,
  '2017 Mazda Mazda6 Touring': 75,
  '2018 Mazda CX-5 Grand Touring': 76,
  '2018 Mazda CX-5 Sport': 77,
  '2018 Mazda CX-5 Touring': 78,
  '2018 Mazda CX-9 Grand Touring': 79,
  '2018 Mazda CX-9 Touring': 80,
  '2018 Mazda MX-5 Miata RF Club': 81,
  '2018 Mazda Mazda3 Grand Touring': 82,
  '2018 Mazda Mazda3 Sport': 83,
  '2018 Mazda Mazda3 Touring': 84,
  '2018 Mazda Mazda6 Grand Touring': 85,
  '2018 Mazda Mazda6 Sport': 86,
  '2018 Mazda Mazda6 Touring': 87,
  '2019 Mazda CX-3 Grand Touring': 88,
  '2019 Mazda CX-3 Sport': 89,
  '2019 Mazda CX-3 Touring': 90,
  '2019 Mazda CX-5 Grand Touring': 91,
  '2019 Mazda CX-5 Grand Touring Reserve': 92,
  '2019 Mazda CX-5 Sport': 93,
  '2019 Mazda CX-5 Touring': 94,
  '2019 Mazda CX-9 Grand Touring': 95,
  '2019 Mazda CX-9 Signature': 96,
  '2019 Mazda CX-9 Sport': 97,
  '2019 Mazda CX-9 Touring': 98,
  '2019 Mazda MX-5 Miata Grand Touring': 99,
  '2019 Mazda MX-5 Miata RF Grand Touring': 100,
  '2019 Mazda MX-5 Miata Sport': 101,
  '2019 Mazda Mazda3 AWD w/Preferred Package': 102,
  '2019 Mazda Mazda3 FWD w/Preferred Package': 103,
  '2019 Mazda Mazda3 FWD w/Select Package': 104,
  '2019 Mazda Mazda6 Grand Touring': 105,
  '2019 Mazda Mazda6 Grand Touring Reserve': 106,
  '2019 Mazda Mazda6 Sport': 107,
  '2019 Mazda Mazda6 Touring': 108,
  '2020 Mazda CX-3 Sport': 109,
  '2020 Mazda CX-30 Preferred': 110,
  '2020 Mazda CX-30 Premium Package': 111,
  '2020 Mazda CX-30 Select': 112,
  '2020 Mazda CX-5 Grand Touring': 113,
  '2020 Mazda CX-5 Grand Touring Reserve': 114,
  '2020 Mazda CX-5 Signature': 115,
  '2020 Mazda CX-5 Touring': 116,
  '2020 Mazda CX-9 Grand Touring': 117,
  '2020 Mazda CX-9 Signature': 118,
  '2020 Mazda CX-9 Sport': 119,
  '2020 Mazda CX-9 Touring': 120,
  '2020 Mazda MX-5 Miata Grand Touring': 121,
  '2020 Mazda MX-5 Miata RF Grand Touring': 122,
  '2020 Mazda MX-5 Miata Sport': 123,
  '2020 Mazda Mazda3 AWD w/Preferred Package': 124,
  '2020 Mazda Mazda3 AWD w/Premium Package': 125,
  '2020 Mazda Mazda3 FWD': 126,
  '2020 Mazda Mazda3 FWD w/Preferred Package': 127,
  '2020 Mazda Mazda3 FWD w/Premium Package': 128,
  '2020 Mazda Mazda3 FWD w/Select Package': 129,
  '2020 Mazda Mazda6 Grand Touring': 130,
  '2020 Mazda Mazda6 Grand Touring Reserve': 131,
  '2020 Mazda Mazda6 Signature': 132,
  '2020 Mazda Mazda6 Touring': 133,
  '2021 Mazda CX-3 Sport': 134,
  '2021 Mazda CX-30 Base': 135,
  '2021 Mazda CX-30 Preferred': 136,
  '2021 Mazda CX-30 Premium Package': 137,
  '2021 Mazda CX-30 Select': 138,
  '2021 Mazda CX-5 Carbon Edition': 139,
  '2021 Mazda CX-5 Grand Touring': 140,
  '2021 Mazda CX-5 Grand Touring Reserve': 141,
  '2021 Mazda CX-5 Signature': 142,
  '2021 Mazda CX-5 Touring': 143,
  '2021 Mazda CX-9 Carbon Edition': 144,
  '2021 Mazda CX-9 Grand Touring': 145,
  '2021 Mazda CX-9 Signature': 146,
  '2021 Mazda CX-9 Sport': 147,
  '2021 Mazda CX-9 Touring': 148,
  '2021 Mazda MX-5 Miata Club': 149,
  '2021 Mazda MX-5 Miata Grand Touring': 150,
  '2021 Mazda MX-5 Miata RF Grand Touring': 151,
  '2021 Mazda Mazda3 2.5 Turbo AWD': 152,
  '2021 Mazda Mazda3 AWD w/Preferred Package': 153,
  '2021 Mazda Mazda3 AWD w/Premium Package': 154,
  '2021 Mazda Mazda3 FWD w/Preferred Package': 155,
  '2021 Mazda Mazda3 FWD w/Premium Package': 156,
  '2021 Mazda Mazda6 Carbon Edition': 157,
  '2021 Mazda Mazda6 Grand Touring': 158,
  '2021 Mazda Mazda6 Grand Touring Reserve': 159,
  '2021 Mazda Mazda6 Sport': 160,
  '2021 Mazda Mazda6 Touring': 161,
  '2022 Mazda CX-30 2.5 S': 162,
  '2022 Mazda CX-30 2.5 S Carbon Edition': 163,
  '2022 Mazda CX-30 2.5 S Preferred Package': 164,
  '2022 Mazda CX-30 2.5 S Select Package': 165,
  '2022 Mazda CX-30 2.5 Turbo Premium Package': 166,
  '2022 Mazda CX-30 2.5 Turbo Premium Plus Package': 167,
  '2022 Mazda CX-30 Premium Package': 168,
  '2022 Mazda CX-30 Select': 169,
  '2022 Mazda CX-5 2.5 S': 170,
  '2022 Mazda CX-5 2.5 S Preferred Package': 171,
  '2022 Mazda CX-5 2.5 S Premium': 172,
  '2022 Mazda CX-5 2.5 S Premium Plus Package': 173,
  '2022 Mazda CX-5 2.5 Turbo': 174,
  '2022 Mazda CX-5 2.5 Turbo Signature': 175,
  '2022 Mazda CX-5 Carbon Edition': 176,
  '2022 Mazda CX-5 Signature': 177,
  '2022 Mazda CX-9 Carbon Edition': 178,
  '2022 Mazda CX-9 Grand Touring': 179,
  '2022 Mazda CX-9 Signature': 180,
  '2022 Mazda CX-9 Sport': 181,
  '2022 Mazda CX-9 Touring': 182,
  '2022 Mazda CX-9 Touring Plus': 183,
  '2022 Mazda MX-30 Base': 184,
  '2022 Mazda MX-30 MX-30 EV': 185,
  '2022 Mazda MX-30 Premium Plus': 186,
  '2022 Mazda MX-5 Miata Club': 187,
  '2022 Mazda MX-5 Miata Grand Touring': 188,
  '2022 Mazda MX-5 Miata RF Grand Touring': 189,
  '2022 Mazda MX-5 Miata Sport': 190,
  '2022 Mazda Mazda3 FWD w/Preferred Package': 191,
  '2022 Mazda Mazda3 Select': 192,
  '2023 Mazda CX-30 2.5 S Preferred Package': 193,
  '2023 Mazda CX-30 2.5 Turbo Premium Package': 194,
  '2023 Mazda CX-30 2.5 Turbo Premium Plus Package': 195,
  '2023 Mazda CX-30 Premium Package': 196,
  '2023 Mazda CX-5 2.5 S Carbon Edition': 197,
  '2023 Mazda CX-5 2.5 S Preferred Package': 198,
  '2023 Mazda CX-5 2.5 S Premium': 199,
  '2023 Mazda CX-5 2.5 S Select Package': 200,
  '2023 Mazda CX-5 Premium Plus': 201,
  '2023 Mazda CX-50 2.5 S Preferred Plus': 202,
  '2023 Mazda CX-50 2.5 S Preferred Plus Package': 203,
  '2023 Mazda CX-50 2.5 S Premium Plus': 204,
  '2023 Mazda CX-50 2.5 S Premium Plus Package': 205,
  '2023 Mazda CX-50 2.5 Turbo': 206,
  '2023 Mazda CX-50 2.5 Turbo Meridian Edition': 207,
  '2023 Mazda CX-50 2.5 Turbo Premium Package': 208,
  '2023 Mazda CX-50 2.5 Turbo Premium Plus Package': 209,
  '2023 Mazda CX-9 Carbon Edition': 210,
  '2023 Mazda CX-9 Grand Touring': 211,
  '2023 Mazda CX-9 Signature': 212,
  '2023 Mazda CX-9 TP': 213,
  '2023 Mazda CX-9 Touring': 214,
  '2023 Mazda CX-9 Touring Plus': 215,
  '2023 Mazda MX-30 EV Premium Plus': 216,
  '2023 Mazda MX-5 Miata Club': 217,
  '2023 Mazda MX-5 Miata Grand Touring': 218,
  '2023 Mazda MX-5 Miata RF Grand Touring': 219,
  '2023 Mazda Mazda3 AWD w/Premium Package': 220,
  '2023 Mazda Mazda3 FWD w/Preferred Package': 221,
  '2023 Mazda Mazda3 FWD w/Select Package': 222,
  '2024 Mazda CX-5 2.5 Turbo Premium': 223,
  '2024 Mazda CX-5 Preferred': 224,
  '2024 Mazda CX-50 2.5 S Preferred Package': 225,
  '2024 Mazda CX-50 2.5 S Premium Plus Package': 226,
  '2024 Mazda CX-90 3.3 Turbo Preferred Plus': 227,
  '2024 Mazda CX-90 3.3 Turbo Premium Plus': 228,
  '2024 Mazda CX-90 3.3 Turbo S Premium': 229,
  '2024 Mazda CX-90 Base': 230,
  '2024 Mazda CX-90 PHEV Base': 231,
  '2024 Mazda CX-90 PHEV Preferred': 232,
  '2024 Mazda CX-90 PHEV Premium': 233,
  '2024 Mazda CX-90 PHEV Premium Plus': 234,
  '2024 Mazda CX-90 Preferred Plus': 235,
  '2024 Mazda CX-90 Premium': 236,
  '2024 Mazda CX-90 Premium Plus': 237,
  '2024 Mazda CX-90 S Premium': 238,
  '2024 Mazda CX-90 S Premium Plus': 239}
model=model_dict[st.sidebar.selectbox("Model",model_dict.keys())]

mil_dict= {'1,310 mi.': 0,
  '1,404 mi.': 1,
  '1,417 mi.': 2,
  '1,526 mi.': 3,
  '1,537 mi.': 4,
  '1,577 mi.': 5,
  '1,752 mi.': 6,
  '1,777 mi.': 7,
  '1,831 mi.': 8,
  '1,921 mi.': 9,
  '1,958 mi.': 10,
  '1,970 mi.': 11,
  '10,007 mi.': 12,
  '10,261 mi.': 13,
  '10,294 mi.': 14,
  '10,558 mi.': 15,
  '10,566 mi.': 16,
  '10,888 mi.': 17,
  '103,252 mi.': 18,
  '103,486 mi.': 19,
  '103,493 mi.': 20,
  '105,736 mi.': 21,
  '108,125 mi.': 22,
  '108,616 mi.': 23,
  '109,513 mi.': 24,
  '109,558 mi.': 25,
  '11,141 mi.': 26,
  '11,193 mi.': 27,
  '11,307 mi.': 28,
  '11,475 mi.': 29,
  '11,502 mi.': 30,
  '11,668 mi.': 31,
  '11,740 mi.': 32,
  '11,772 mi.': 33,
  '11,815 mi.': 34,
  '11,980 mi.': 35,
  '110,424 mi.': 36,
  '110,446 mi.': 37,
  '112,722 mi.': 38,
  '114,720 mi.': 39,
  '116,839 mi.': 40,
  '118,560 mi.': 41,
  '119,065 mi.': 42,
  '12,259 mi.': 43,
  '12,567 mi.': 44,
  '12,639 mi.': 45,
  '12,891 mi.': 46,
  '12,981 mi.': 47,
  '121 mi.': 48,
  '123,127 mi.': 49,
  '124,428 mi.': 50,
  '124,774 mi.': 51,
  '125,091 mi.': 52,
  '125,518 mi.': 53,
  '125,779 mi.': 54,
  '128,426 mi.': 55,
  '13,018 mi.': 56,
  '13,067 mi.': 57,
  '13,162 mi.': 58,
  '13,335 mi.': 59,
  '13,606 mi.': 60,
  '13,615 mi.': 61,
  '13,724 mi.': 62,
  '13,883 mi.': 63,
  '13,905 mi.': 64,
  '130,380 mi.': 65,
  '131,628 mi.': 66,
  '133,786 mi.': 67,
  '134,570 mi.': 68,
  '134,999 mi.': 69,
  '135,911 mi.': 70,
  '137,233 mi.': 71,
  '137,600 mi.': 72,
  '139,824 mi.': 73,
  '14,042 mi.': 74,
  '14,225 mi.': 75,
  '14,291 mi.': 76,
  '14,456 mi.': 77,
  '14,546 mi.': 78,
  '14,665 mi.': 79,
  '14,833 mi.': 80,
  '140,000 mi.': 81,
  '140,025 mi.': 82,
  '147,098 mi.': 83,
  '148,596 mi.': 84,
  '149,987 mi.': 85,
  '15,046 mi.': 86,
  '15,051 mi.': 87,
  '15,123 mi.': 88,
  '15,149 mi.': 89,
  '15,251 mi.': 90,
  '15,529 mi.': 91,
  '15,669 mi.': 92,
  '15,794 mi.': 93,
  '151,850 mi.': 94,
  '157,447 mi.': 95,
  '157,622 mi.': 96,
  '16,070 mi.': 97,
  '16,118 mi.': 98,
  '16,198 mi.': 99,
  '16,336 mi.': 100,
  '16,705 mi.': 101,
  '16,847 mi.': 102,
  '16,878 mi.': 103,
  '163,990 mi.': 104,
  '17,072 mi.': 105,
  '17,129 mi.': 106,
  '17,218 mi.': 107,
  '17,226 mi.': 108,
  '17,324 mi.': 109,
  '17,567 mi.': 110,
  '17,662 mi.': 111,
  '17,762 mi.': 112,
  '17,921 mi.': 113,
  '173 mi.': 114,
  '18,141 mi.': 115,
  '18,292 mi.': 116,
  '18,580 mi.': 117,
  '18,991 mi.': 118,
  '19,111 mi.': 119,
  '19,769 mi.': 120,
  '19,906 mi.': 121,
  '193,539 mi.': 122,
  '2,036 mi.': 123,
  '2,158 mi.': 124,
  '2,345 mi.': 125,
  '2,414 mi.': 126,
  '2,474 mi.': 127,
  '2,537 mi.': 128,
  '2,548 mi.': 129,
  '2,598 mi.': 130,
  '2,774 mi.': 131,
  '2,801 mi.': 132,
  '2,852 mi.': 133,
  '2,930 mi.': 134,
  '2,949 mi.': 135,
  '2,959 mi.': 136,
  '2,986 mi.': 137,
  '20,012 mi.': 138,
  '20,061 mi.': 139,
  '20,210 mi.': 140,
  '20,460 mi.': 141,
  '20,845 mi.': 142,
  '21,074 mi.': 143,
  '21,540 mi.': 144,
  '21,578 mi.': 145,
  '21,589 mi.': 146,
  '21,944 mi.': 147,
  '21,969 mi.': 148,
  '219,200 mi.': 149,
  '22,184 mi.': 150,
  '22,228 mi.': 151,
  '22,333 mi.': 152,
  '22,344 mi.': 153,
  '22,549 mi.': 154,
  '22,601 mi.': 155,
  '22,692 mi.': 156,
  '22,826 mi.': 157,
  '22,969 mi.': 158,
  '23,015 mi.': 159,
  '23,028 mi.': 160,
  '23,266 mi.': 161,
  '23,466 mi.': 162,
  '23,524 mi.': 163,
  '23,551 mi.': 164,
  '23,675 mi.': 165,
  '23,707 mi.': 166,
  '23,751 mi.': 167,
  '23,941 mi.': 168,
  '24,540 mi.': 169,
  '24,622 mi.': 170,
  '24,758 mi.': 171,
  '24,828 mi.': 172,
  '24,850 mi.': 173,
  '25,015 mi.': 174,
  '25,023 mi.': 175,
  '25,048 mi.': 176,
  '25,168 mi.': 177,
  '25,616 mi.': 178,
  '25,624 mi.': 179,
  '25,637 mi.': 180,
  '26,389 mi.': 181,
  '26,490 mi.': 182,
  '26,536 mi.': 183,
  '26,663 mi.': 184,
  '26,928 mi.': 185,
  '26,964 mi.': 186,
  '27,122 mi.': 187,
  '27,305 mi.': 188,
  '27,553 mi.': 189,
  '27,816 mi.': 190,
  '27,851 mi.': 191,
  '27,874 mi.': 192,
  '27,981 mi.': 193,
  '27,996 mi.': 194,
  '28,060 mi.': 195,
  '28,780 mi.': 196,
  '28,985 mi.': 197,
  '29,028 mi.': 198,
  '29,035 mi.': 199,
  '29,063 mi.': 200,
  '29,133 mi.': 201,
  '29,516 mi.': 202,
  '29,554 mi.': 203,
  '29,564 mi.': 204,
  '29,567 mi.': 205,
  '29,626 mi.': 206,
  '29,685 mi.': 207,
  '29,994 mi.': 208,
  '3,000 mi.': 209,
  '3,026 mi.': 210,
  '3,056 mi.': 211,
  '3,105 mi.': 212,
  '3,144 mi.': 213,
  '3,156 mi.': 214,
  '3,171 mi.': 215,
  '3,268 mi.': 216,
  '3,307 mi.': 217,
  '3,400 mi.': 218,
  '3,436 mi.': 219,
  '3,466 mi.': 220,
  '3,477 mi.': 221,
  '3,600 mi.': 222,
  '3,751 mi.': 223,
  '3,778 mi.': 224,
  '3,895 mi.': 225,
  '3,994 mi.': 226,
  '30,073 mi.': 227,
  '30,102 mi.': 228,
  '30,199 mi.': 229,
  '30,471 mi.': 230,
  '30,603 mi.': 231,
  '30,731 mi.': 232,
  '30,920 mi.': 233,
  '30,952 mi.': 234,
  '31,010 mi.': 235,
  '31,201 mi.': 236,
  '31,800 mi.': 237,
  '32,088 mi.': 238,
  '32,150 mi.': 239,
  '32,164 mi.': 240,
  '32,289 mi.': 241,
  '32,509 mi.': 242,
  '33,071 mi.': 243,
  '33,228 mi.': 244,
  '33,396 mi.': 245,
  '33,859 mi.': 246,
  '34,354 mi.': 247,
  '34,507 mi.': 248,
  '34,613 mi.': 249,
  '35,030 mi.': 250,
  '35,124 mi.': 251,
  '35,131 mi.': 252,
  '35,475 mi.': 253,
  '35,550 mi.': 254,
  '35,837 mi.': 255,
  '35,886 mi.': 256,
  '36,043 mi.': 257,
  '36,402 mi.': 258,
  '36,708 mi.': 259,
  '36,763 mi.': 260,
  '37,316 mi.': 261,
  '37,592 mi.': 262,
  '37,716 mi.': 263,
  '37,786 mi.': 264,
  '38,255 mi.': 265,
  '38,383 mi.': 266,
  '38,526 mi.': 267,
  '38,675 mi.': 268,
  '38,788 mi.': 269,
  '38,806 mi.': 270,
  '38,899 mi.': 271,
  '39,205 mi.': 272,
  '39,467 mi.': 273,
  '39,585 mi.': 274,
  '39,646 mi.': 275,
  '39,814 mi.': 276,
  '39,871 mi.': 277,
  '39,918 mi.': 278,
  '4,002 mi.': 279,
  '4,022 mi.': 280,
  '4,055 mi.': 281,
  '4,071 mi.': 282,
  '4,194 mi.': 283,
  '4,243 mi.': 284,
  '4,321 mi.': 285,
  '4,398 mi.': 286,
  '4,433 mi.': 287,
  '4,448 mi.': 288,
  '4,479 mi.': 289,
  '4,588 mi.': 290,
  '4,648 mi.': 291,
  '4,650 mi.': 292,
  '4,705 mi.': 293,
  '4,749 mi.': 294,
  '4,846 mi.': 295,
  '40,143 mi.': 296,
  '40,430 mi.': 297,
  '40,459 mi.': 298,
  '40,744 mi.': 299,
  '40,760 mi.': 300,
  '41,027 mi.': 301,
  '41,087 mi.': 302,
  '41,223 mi.': 303,
  '41,363 mi.': 304,
  '41,891 mi.': 305,
  '41,904 mi.': 306,
  '42,390 mi.': 307,
  '42,407 mi.': 308,
  '42,836 mi.': 309,
  '429 mi.': 310,
  '43,146 mi.': 311,
  '43,355 mi.': 312,
  '43,363 mi.': 313,
  '43,735 mi.': 314,
  '44,021 mi.': 315,
  '44,237 mi.': 316,
  '44,389 mi.': 317,
  '44,698 mi.': 318,
  '44,741 mi.': 319,
  '44,949 mi.': 320,
  '44,970 mi.': 321,
  '45,060 mi.': 322,
  '45,297 mi.': 323,
  '45,631 mi.': 324,
  '46,123 mi.': 325,
  '47,067 mi.': 326,
  '47,087 mi.': 327,
  '47,561 mi.': 328,
  '47,615 mi.': 329,
  '47,778 mi.': 330,
  '48,234 mi.': 331,
  '48,317 mi.': 332,
  '48,817 mi.': 333,
  '48,995 mi.': 334,
  '49,066 mi.': 335,
  '49,311 mi.': 336,
  '49,403 mi.': 337,
  '49,556 mi.': 338,
  '49,731 mi.': 339,
  '495 mi.': 340,
  '5,142 mi.': 341,
  '5,149 mi.': 342,
  '5,366 mi.': 343,
  '5,390 mi.': 344,
  '5,528 mi.': 345,
  '5,557 mi.': 346,
  '5,598 mi.': 347,
  '5,734 mi.': 348,
  '5,846 mi.': 349,
  '5,898 mi.': 350,
  '5,911 mi.': 351,
  '50,134 mi.': 352,
  '50,444 mi.': 353,
  '50,659 mi.': 354,
  '50,867 mi.': 355,
  '51,330 mi.': 356,
  '51,375 mi.': 357,
  '51,808 mi.': 358,
  '52,704 mi.': 359,
  '52,713 mi.': 360,
  '52,745 mi.': 361,
  '52,833 mi.': 362,
  '53,058 mi.': 363,
  '53,547 mi.': 364,
  '53,575 mi.': 365,
  '54,694 mi.': 366,
  '56,266 mi.': 367,
  '56,652 mi.': 368,
  '56,929 mi.': 369,
  '57,029 mi.': 370,
  '57,217 mi.': 371,
  '58,262 mi.': 372,
  '58,474 mi.': 373,
  '58,712 mi.': 374,
  '58,790 mi.': 375,
  '59,166 mi.': 376,
  '59,378 mi.': 377,
  '59,478 mi.': 378,
  '59,922 mi.': 379,
  '594 mi.': 380,
  '6,027 mi.': 381,
  '6,050 mi.': 382,
  '6,230 mi.': 383,
  '6,245 mi.': 384,
  '6,356 mi.': 385,
  '6,361 mi.': 386,
  '6,527 mi.': 387,
  '6,617 mi.': 388,
  '6,696 mi.': 389,
  '6,731 mi.': 390,
  '6,768 mi.': 391,
  '6,843 mi.': 392,
  '6,915 mi.': 393,
  '60,081 mi.': 394,
  '60,422 mi.': 395,
  '60,577 mi.': 396,
  '61,011 mi.': 397,
  '61,064 mi.': 398,
  '61,167 mi.': 399,
  '61,402 mi.': 400,
  '61,482 mi.': 401,
  '61,736 mi.': 402,
  '61,869 mi.': 403,
  '62,001 mi.': 404,
  '62,236 mi.': 405,
  '62,349 mi.': 406,
  '63,078 mi.': 407,
  '63,090 mi.': 408,
  '63,449 mi.': 409,
  '63,777 mi.': 410,
  '63,807 mi.': 411,
  '64,064 mi.': 412,
  '64,364 mi.': 413,
  '64,667 mi.': 414,
  '643 mi.': 415,
  '65,017 mi.': 416,
  '65,746 mi.': 417,
  '65,931 mi.': 418,
  '66,025 mi.': 419,
  '66,167 mi.': 420,
  '66,176 mi.': 421,
  '66,633 mi.': 422,
  '66,646 mi.': 423,
  '66,652 mi.': 424,
  '66,667 mi.': 425,
  '67,371 mi.': 426,
  '67,669 mi.': 427,
  '67,993 mi.': 428,
  '68,363 mi.': 429,
  '69,201 mi.': 430,
  '69,245 mi.': 431,
  '69,251 mi.': 432,
  '7,220 mi.': 433,
  '7,274 mi.': 434,
  '7,485 mi.': 435,
  '7,859 mi.': 436,
  '7,891 mi.': 437,
  '7,919 mi.': 438,
  '70,457 mi.': 439,
  '70,705 mi.': 440,
  '70,742 mi.': 441,
  '71,118 mi.': 442,
  '71,236 mi.': 443,
  '71,371 mi.': 444,
  '71,431 mi.': 445,
  '71,899 mi.': 446,
  '71,956 mi.': 447,
  '72,283 mi.': 448,
  '72,835 mi.': 449,
  '73,351 mi.': 450,
  '73,575 mi.': 451,
  '736 mi.': 452,
  '752 mi.': 453,
  '76,106 mi.': 454,
  '76,767 mi.': 455,
  '77,530 mi.': 456,
  '77,821 mi.': 457,
  '77,941 mi.': 458,
  '78,136 mi.': 459,
  '78,386 mi.': 460,
  '79,107 mi.': 461,
  '795 mi.': 462,
  '799 mi.': 463,
  '8,160 mi.': 464,
  '8,167 mi.': 465,
  '8,442 mi.': 466,
  '8,551 mi.': 467,
  '8,732 mi.': 468,
  '8,740 mi.': 469,
  '8,744 mi.': 470,
  '8,994 mi.': 471,
  '80,259 mi.': 472,
  '80,343 mi.': 473,
  '81,339 mi.': 474,
  '81,360 mi.': 475,
  '83,168 mi.': 476,
  '83,197 mi.': 477,
  '83,748 mi.': 478,
  '84,020 mi.': 479,
  '85,284 mi.': 480,
  '85,317 mi.': 481,
  '85,394 mi.': 482,
  '85,683 mi.': 483,
  '86,082 mi.': 484,
  '86,554 mi.': 485,
  '87,695 mi.': 486,
  '88,646 mi.': 487,
  '88,783 mi.': 488,
  '88,919 mi.': 489,
  '89,733 mi.': 490,
  '89,838 mi.': 491,
  '9,064 mi.': 492,
  '9,092 mi.': 493,
  '9,257 mi.': 494,
  '9,366 mi.': 495,
  '9,455 mi.': 496,
  '9,623 mi.': 497,
  '9,779 mi.': 498,
  '9,977 mi.': 499,
  '90,635 mi.': 500,
  '90,946 mi.': 501,
  '91,567 mi.': 502,
  '92,175 mi.': 503,
  '92,522 mi.': 504,
  '92,586 mi.': 505,
  '92,653 mi.': 506,
  '93,939 mi.': 507,
  '94,115 mi.': 508,
  '94,903 mi.': 509,
  '95,746 mi.': 510,
  '96,097 mi.': 511,
  '96,280 mi.': 512,
  '96,670 mi.': 513,
  '98,776 mi.': 514,
  '98,922 mi.': 515}

mil=mil_dict[st.sidebar.selectbox("Mil",model_dict.keys())]

kullanım_durumu_dict={'Used': 0}
kullanım_durumu=kullanım_durumu_dict[st.sidebar.selectbox("Kullanım Durumu",kullanım_durumu_dict.keys())]

features={'model':model,'mil':mil,'kullanım_durumu':kullanım_durumu}

features_df=pd.DataFrame([features])

st.table(features_df)

if st.button("button"):
    pred=predict_price(model,features_df)
    st.write(f"Tahmin edilen değer:{pred}")
# Out:
# ---------------------------------------------------------------------------
# CatBoostError                             Traceback (most recent call last)
# Cell In[1], line 6
#       3 import pandas as pd
#       5 model=CatBoostRegressor
# ----> 6 model.load_model("model.cbm")
#       8 def predict_price(cbm,df):
#       9     pred=model.predict(df)
#
# File ~\anaconda3\Lib\site-packages\catboost\core.py:3322, in CatBoost.load_model(self, fname, format, stream, blob)
#    3313 """
#    3314 Load model from a file, stream or blob.
#    3315
#    (...)
#    3319     Input file name.
#    3320 """
#    3321 if (fname is None) + (stream is None) + (blob is None) != 2:
# -> 3322     raise CatBoostError("Exactly one of fname/stream/blob arguments mustn't be None")
#    3324 if fname is not None:
#    3325     self._load_model(fname, format)
#
# CatBoostError: Exactly one of fname/stream/blob arguments mustn't be None

# %%
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Out:
#   Cell In[2], line 1
#     python -m streamlit run Untitled2
#               ^
# SyntaxError: invalid syntax
